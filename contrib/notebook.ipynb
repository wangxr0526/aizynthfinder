# %% [markdown]
# # AiZynthFinder
#
# Click the ▶ play button at the left of the **Installation** text below to install the application. The initial installation process may take a few minutes. Then run **Start application** cell.
#
# 1. Enter the target compound [SMILES][1] code.
# 3. Click the **Run Search** button to start the algorithm.
# 4. Once it stops serching, click the **Show Reactions** button.
#
# [1]: https://en.wikipedia.org/wiki/Simplified_molecular-input_line-entry_system

# %%
#@title Installation -- Run this cell to install AiZynthFinder

# This might not install the dependencies that you need
#!(AIZ_LATEST_TAG=$(git -c 'versionsort.suffix=-' \
#    ls-remote --exit-code --refs --sort='version:refname' --tags https://github.com/MolecularAI/aizynthfinder '*.*.*' \
#    | tail --lines=1 \
#    | cut -f 3 -d /) \
#  && pip install --quiet https://github.com/MolecularAI/aizynthfinder/archive/${AIZ_LATEST_TAG}.tar.gz)
# !pip install --quiet aizynthfinder[all]
# !pip install --ignore-installed Pillow==9.0.0
# !mkdir --parents data && download_public_data data

# %%
#@title Start application. {display-mode: "form"}

from rdkit.Chem.Draw import IPythonConsole
from aizynthfinder.interfaces import AiZynthApp
application = AiZynthApp("./data/config.yml")
# Out:
# Loading template-based expansion policy model from /home/xiaoruiwang/data/ubuntu_work_beta/multi_step_work/aizynthfinder/contrib/data/uspto_model.onnx to uspto
# Loading templates from /home/xiaoruiwang/data/ubuntu_work_beta/multi_step_work/aizynthfinder/contrib/data/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /home/xiaoruiwang/data/ubuntu_work_beta/multi_step_work/aizynthfinder/contrib/data/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /home/xiaoruiwang/data/ubuntu_work_beta/multi_step_work/aizynthfinder/contrib/data/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /home/xiaoruiwang/data/ubuntu_work_beta/multi_step_work/aizynthfinder/contrib/data/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Loading stock from InMemoryInchiKeyQuery to uspto_stock
# Text(value='', continuous_update=False, description='SMILES')
# Output(layout=Layout(border='1px solid silver', height='180px', width='50%'))
# HBox(children=(VBox(children=(Label(value='Stocks'), Checkbox(value=True, description='zinc', style=Descriptio…
# HBox(children=(Button(description='Run Search', style=ButtonStyle()), Button(description='Extend Search', styl…
# Output(layout=Layout(border='1px solid silver', height='320px', overflow='auto', width='99%'))
# HBox(children=(Button(description='Show Reactions', style=ButtonStyle()), Dropdown(description='Routes: ', opt…
# Output(layout=Layout(border='1px solid silver', width='99%'))

# %% [markdown]
# # Bibliography
#
# _Genheden S, Thakkar A, Chadimova V, et al (2020) AiZynthFinder: a fast, robust and flexible open-source software for retrosynthetic planning. J. Cheminf. https://doi.org/10.1186/s13321-020-00472-1 ([GitHub](https://github.com/MolecularAI/aizynthfinder) & [Documentation](https://molecularai.github.io/aizynthfinder/html/index.html))_
